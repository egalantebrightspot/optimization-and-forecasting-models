# %% [markdown]
# # 01 – Linear Programming for Resource Allocation
#
# This notebook will demonstrate how to formulate and solve linear programming models for resource allocation using the `src/optimization` package.
