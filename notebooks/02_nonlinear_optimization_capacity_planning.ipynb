# %% [markdown]
# # 02 – Nonlinear Optimization for Capacity Planning
#
# This notebook will cover nonlinear optimization approaches for capacity planning problems using the `src/optimization` package.
